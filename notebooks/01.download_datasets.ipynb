# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file :
    data = json.load(file)

# %%
data
# Out:
# {'username': 'apsaraima', 'key': '4c7ef57bc7e74345d6c9c8e6de56b03d'}

# %%
# %pip install kaggle
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ['KAGGLE_USERNAME']= data['username']
os.environ['KAGGLE_KEY']=data['key']

# %%
from kaggle.api.kaggle_api_extended import kaggleApi
api = kaggleApi()
api.authenticate()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from kaggle.api.kaggle_api_extended import kaggleApi
#       2 api = kaggleApi()
#       3 api.authenticate()
#
# ImportError: cannot import name 'kaggleApi' from 'kaggle.api.kaggle_api_extended' (C:\Users\User\Desktop\foodDrug_Interaction-Project\env\Lib\site-packages\kaggle\api\kaggle_api_extended.py)

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('nipunaudara/nutritional-facts-for-most-common-sri-lankan-foods', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nipunaudara/nutritional-facts-for-most-common-sri-lankan-foods

# %%
import zipfile
with zipfile.ZipFile('../artifacts/nutritional-facts-for-most-common-sri-lankan-foods.zip','r') as zip_ref:
    zip_ref.extractall('../artifacts/')
