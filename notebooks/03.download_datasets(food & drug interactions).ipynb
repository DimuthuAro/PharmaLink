# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file :
    data = json.load(file)

# %%
data
# Out:
# {'username': 'apsaraima', 'key': '4c7ef57bc7e74345d6c9c8e6de56b03d'}

# %%
import os
os.environ['KAGGLE_USERNAME']= data['username']
os.environ['KAGGLE_KEY']=data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('shayanhusain/drug-food-interactions-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shayanhusain/drug-food-interactions-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/drug-food-interactions-dataset.zip','r') as zip_ref:
    zip_ref.extractall('../artifacts/')
